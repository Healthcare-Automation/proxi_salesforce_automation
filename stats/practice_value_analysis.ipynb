# %%
import pandas as pd

df = pd.read_csv("/Users/andylee/Desktop/projects/proxi/proxi_salesforce_automation/data/salesforce_jobs.csv")

# Check any duplicates for Job_Client_Job_Id__c
df.groupby("Job_Client_Job_Id__c").size().sort_values(ascending=False)
# Out:
# Job_Client_Job_Id__c
# 0030 - Fairfield, CT                     1
# 4136- Grand Prairie, TX                  1
# 4120- Jasper, IN                         1
# 4121- Fresno, CA (West)                  1
# 4122- Euless, TX                         1
#                                         ..
# 2449 - Madison, WI                       1
# 2454- San Angelo, TX                     1
# 2459 - Ocala, FL (Silver Springs         1
# 2463 - Jacksonville, FL (Orange Park)    1
# A0997                                    1
# Length: 820, dtype: int64
